# %% [markdown]
# ## VGG ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU



from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'dataset/train',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 1699 images belonging to 2 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'dataset/test',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 1699 images belonging to 2 classes.

# %%
def vgg(input_shape, n_classes):
  
  input = Input(input_shape)
  
  x = Conv2D(64, 3, padding='same', activation='relu')(input)
  x = Conv2D(64, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(128, 3, padding='same', activation='relu')(x)
  x = Conv2D(128, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Flatten()(x)
  x = Dense(4096, activation='relu')(x)
  x = Dense(4096, activation='relu')(x)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model

input_shape = 224, 224, 3
n_classes = 2

K.clear_session()
model = vgg(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 134268738 (512.19 MB)
# Trainable params: 134268738 (512.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_path = "VGG.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 20
batch_size = 312

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\env\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5/5 [==============================] - ETA: 0s - loss: 1.7357 - accuracy: 0.4938 - precision: 0.4938
# Epoch 1: accuracy improved from -inf to 0.49375, saving model to VGG.h5
# 5/5 [==============================] - 321s 58s/step - loss: 1.7357 - accuracy: 0.4938 - precision: 0.4938 - val_loss: 0.6859 - val_accuracy: 0.5813 - val_precision: 0.5813
# Epoch 2/20
# 5/5 [==============================] - ETA: 0s - loss: 0.7918 - accuracy: 0.5688 - precision: 0.5688
# Epoch 2: accuracy improved from 0.49375 to 0.56875, saving model to VGG.h5
# 5/5 [==============================] - 263s 56s/step - loss: 0.7918 - accuracy: 0.5688 - precision: 0.5688 - val_loss: 0.6908 - val_accuracy: 0.5375 - val_precision: 0.5375
# Epoch 3/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6961 - accuracy: 0.4750 - precision: 0.4750
# Epoch 3: accuracy did not improve from 0.56875
# 5/5 [==============================] - 241s 47s/step - loss: 0.6961 - accuracy: 0.4750 - precision: 0.4750 - val_loss: 0.6934 - val_accuracy: 0.4812 - val_precision: 0.4812
# Epoch 4/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5813 - precision: 0.5813
# Epoch 4: accuracy improved from 0.56875 to 0.58125, saving model to VGG.h5
# 5/5 [==============================] - 248s 52s/step - loss: 0.6917 - accuracy: 0.5813 - precision: 0.5813 - val_loss: 0.6931 - val_accuracy: 0.5063 - val_precision: 0.5063
# Epoch 5/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5312 - precision: 0.5312
# Epoch 5: accuracy did not improve from 0.58125
# 5/5 [==============================] - 229s 46s/step - loss: 0.6922 - accuracy: 0.5312 - precision: 0.5312 - val_loss: 0.6870 - val_accuracy: 0.5875 - val_precision: 0.5875
# Epoch 6/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5125 - precision: 0.5125
# Epoch 6: accuracy did not improve from 0.58125
# 5/5 [==============================] - 225s 46s/step - loss: 0.6933 - accuracy: 0.5125 - precision: 0.5125 - val_loss: 0.6916 - val_accuracy: 0.5312 - val_precision: 0.5312
# Epoch 7/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5625 - precision: 0.5625
# Epoch 7: accuracy did not improve from 0.58125
# 5/5 [==============================] - 224s 46s/step - loss: 0.6894 - accuracy: 0.5625 - precision: 0.5625 - val_loss: 0.6976 - val_accuracy: 0.4750 - val_precision: 0.4750
# Epoch 8/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.4563 - precision: 0.4563
# Epoch 8: accuracy did not improve from 0.58125
# 5/5 [==============================] - 229s 47s/step - loss: 0.6994 - accuracy: 0.4563 - precision: 0.4563 - val_loss: 0.6919 - val_accuracy: 0.5250 - val_precision: 0.5250
# Epoch 9/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.5562 - precision: 0.5562
# Epoch 9: accuracy did not improve from 0.58125
# 5/5 [==============================] - 224s 46s/step - loss: 0.6897 - accuracy: 0.5562 - precision: 0.5562 - val_loss: 0.6876 - val_accuracy: 0.5813 - val_precision: 0.5813
# Epoch 10/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5063 - precision: 0.5063
# Epoch 10: accuracy did not improve from 0.58125
# 5/5 [==============================] - 222s 46s/step - loss: 0.6935 - accuracy: 0.5063 - precision: 0.5063 - val_loss: 0.6920 - val_accuracy: 0.5250 - val_precision: 0.5250
# Epoch 11/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.4875 - precision: 0.4875
# Epoch 11: accuracy did not improve from 0.58125
# 5/5 [==============================] - 229s 47s/step - loss: 0.6947 - accuracy: 0.4875 - precision: 0.4875 - val_loss: 0.6958 - val_accuracy: 0.4688 - val_precision: 0.4688
# Epoch 12/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6858 - accuracy: 0.6107 - precision: 0.6107
# Epoch 12: accuracy improved from 0.58125 to 0.61069, saving model to VGG.h5
# 5/5 [==============================] - 210s 51s/step - loss: 0.6858 - accuracy: 0.6107 - precision: 0.6107 - val_loss: 0.6998 - val_accuracy: 0.4375 - val_precision: 0.4375
# Epoch 13/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.4504 - precision: 0.4504
# Epoch 13: accuracy did not improve from 0.61069
# 5/5 [==============================] - 192s 38s/step - loss: 0.6997 - accuracy: 0.4504 - precision: 0.4504 - val_loss: 0.6961 - val_accuracy: 0.4875 - val_precision: 0.4875
# Epoch 14/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6974 - accuracy: 0.4750 - precision: 0.4750
# Epoch 14: accuracy did not improve from 0.61069
# 5/5 [==============================] - 227s 47s/step - loss: 0.6974 - accuracy: 0.4750 - precision: 0.4750 - val_loss: 0.7019 - val_accuracy: 0.4250 - val_precision: 0.4250
# Epoch 15/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5750 - precision: 0.5750
# Epoch 15: accuracy did not improve from 0.61069
# 5/5 [==============================] - 226s 46s/step - loss: 0.6870 - accuracy: 0.5750 - precision: 0.5750 - val_loss: 0.6907 - val_accuracy: 0.5375 - val_precision: 0.5375
# Epoch 16/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6972 - accuracy: 0.4688 - precision: 0.4688
# Epoch 16: accuracy did not improve from 0.61069
# 5/5 [==============================] - 223s 46s/step - loss: 0.6972 - accuracy: 0.4688 - precision: 0.4688 - val_loss: 0.6919 - val_accuracy: 0.5250 - val_precision: 0.5250
# Epoch 17/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.4812 - precision: 0.4812
# Epoch 17: accuracy did not improve from 0.61069
# 5/5 [==============================] - 224s 46s/step - loss: 0.6952 - accuracy: 0.4812 - precision: 0.4812 - val_loss: 0.6908 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 18/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6946 - accuracy: 0.4809 - precision: 0.4809
# Epoch 18: accuracy did not improve from 0.61069
# 5/5 [==============================] - 189s 37s/step - loss: 0.6946 - accuracy: 0.4809 - precision: 0.4809 - val_loss: 0.6923 - val_accuracy: 0.5500 - val_precision: 0.5500
# Epoch 19/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4625 - precision: 0.4625
# Epoch 19: accuracy did not improve from 0.61069
# 5/5 [==============================] - 223s 46s/step - loss: 0.6933 - accuracy: 0.4625 - precision: 0.4625 - val_loss: 0.6924 - val_accuracy: 0.5562 - val_precision: 0.5562
# Epoch 20/20
# 5/5 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5375 - precision: 0.5375
# Epoch 20: accuracy did not improve from 0.61069
# 5/5 [==============================] - 230s 47s/step - loss: 0.6928 - accuracy: 0.5375 - precision: 0.5375 - val_loss: 0.6941 - val_accuracy: 0.4812 - val_precision: 0.4812

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
